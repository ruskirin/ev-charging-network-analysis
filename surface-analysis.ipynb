# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from pathlib import Path
import regex as re
from openpyxl import load_workbook

# %%
path_desc = Path('data/features-desc.csv')
path_ev = Path('data/EV_Charging_Stations_Jan312023.xlsx')
path_geo = Path('data/uscities.xlsx')

# %%
desc = pd.read_csv(path_desc)
desc.head()
# Out:
#                       name                                               desc
# 0           fuel_type_code  The type of alternative fuel the station provi...  \
# 1             station_name                           The name of the station.
# 2           street_address      The street address of the station's location.
# 3  intersection_directions  Brief additional information about how to loca...
# 4                     city                The city of the station's location.
#
#    null_values
# 0            0
# 1            2
# 2           34
# 3        51600
# 4            0

# %%
def describe(n):
    try:
        return desc.loc[desc['name']==n, 'desc'].to_numpy()[0]
    except (IndexError, KeyError) as e:
        return None

# %%
data = pd.read_excel(path_ev, sheet_name='Raw', engine='openpyxl')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54238 entries, 0 to 54237
# Data columns (total 69 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Fuel Type Code                    54238 non-null  object
#  1   Station Name                      54236 non-null  object
#  2   Street Address                    54204 non-null  object
#  3   Intersection Directions           2637 non-null   object
#  4   City                              54238 non-null  object
#  5   State                             54236 non-null  object
#  6   ZIP                               54238 non-null  object
#  7   Plus4                             0 non-null      float64
#  8   Station Phone                     50826 non-null  object
#  9   Status Code                       54238 non-null  object
#  10  Expected Date                     0 non-null      float64
#  11  Groups With Access Code           54238 non-null  object
#  12  Access Days Time                  45802 non-null  object
#  13  Cards Accepted                    3978 non-null   object
#  14  BD Blends                         0 non-null      float64
#  15  NG Fill Type Code                 0 non-null      float64
#  16  NG PSI                            0 non-null      float64
#  17  EV Level1 EVSE Num                700 non-null    float64
#  18  EV Level2 EVSE Num                48014 non-null  float64
#  19  EV DC Fast Count                  6974 non-null   float64
#  20  EV Other Info                     50 non-null     object
#  21  EV Network                        54236 non-null  object
#  22  EV Network Web                    45117 non-null  object
#  23  Geocode Status                    54238 non-null  object
#  24  Latitude                          54238 non-null  float64
#  25  Longitude                         54238 non-null  float64
#  26  Date Last Confirmed               53930 non-null  datetime64[ns]
#  27  ID                                54238 non-null  int64
#  28  Updated At                        54238 non-null  object
#  29  Owner Type Code                   18066 non-null  object
#  30  Federal Agency ID                 1051 non-null   float64
#  31  Federal Agency Name               1051 non-null   object
#  32  Open Date                         54219 non-null  datetime64[ns]
#  33  Hydrogen Status Link              0 non-null      float64
#  34  NG Vehicle Class                  0 non-null      float64
#  35  LPG Primary                       0 non-null      float64
#  36  E85 Blender Pump                  0 non-null      float64
#  37  EV Connector Types                54190 non-null  object
#  38  Country                           54238 non-null  object
#  39  Intersection Directions (French)  0 non-null      float64
#  40  Access Days Time (French)         0 non-null      float64
#  41  BD Blends (French)                0 non-null      float64
#  42  Groups With Access Code (French)  54238 non-null  object
#  43  Hydrogen Is Retail                0 non-null      float64
#  44  Access Code                       54238 non-null  object
#  45  Access Detail Code                4554 non-null   object
#  46  Federal Agency Code               1051 non-null   object
#  47  Facility Type                     16733 non-null  object
#  48  CNG Dispenser Num                 0 non-null      float64
#  49  CNG On-Site Renewable Source      0 non-null      float64
#  50  CNG Total Compression Capacity    0 non-null      float64
#  51  CNG Storage Capacity              0 non-null      float64
#  52  LNG On-Site Renewable Source      0 non-null      float64
#  53  E85 Other Ethanol Blends          0 non-null      float64
#  54  EV Pricing                        15314 non-null  object
#  55  EV Pricing (French)               0 non-null      float64
#  56  LPG Nozzle Types                  0 non-null      float64
#  57  Hydrogen Pressures                0 non-null      float64
#  58  Hydrogen Standards                0 non-null      float64
#  59  CNG Fill Type Code                0 non-null      float64
#  60  CNG PSI                           0 non-null      float64
#  61  CNG Vehicle Class                 0 non-null      float64
#  62  LNG Vehicle Class                 0 non-null      float64
#  63  EV On-Site Renewable Source       361 non-null    object
#  64  Restricted Access                 9105 non-null   float64
#  65  RD Blends                         0 non-null      float64
#  66  RD Blends (French)                0 non-null      float64
#  67  RD Blended with Biodiesel         0 non-null      float64
#  68  RD Maximum Biodiesel Level        0 non-null      float64
# dtypes: datetime64[ns](2), float64(38), int64(1), object(28)
# memory usage: 28.6+ MB

# %% [markdown]
# #### NOTE:
# Many empty columns not related to electric vehicles

# %%
data = data.rename(lambda x: x.lower().replace('-', '').replace(' ', '_'), axis=1)
data.head()
# Out:
#   fuel_type_code                      station_name      street_address
# 0           ELEC     Alaska Electric Light & Power    5601 Tonsgard Ct  \
# 1           ELEC             Marine Parking Garage      292 Marine Way
# 2           ELEC                 Juneau Hydropower  8585 Old Dairy Hwy
# 3           ELEC          CHUGACH SOUTH CHUGACH EV    5601 Electron Dr
# 4           ELEC  Whistle Hill - Tesla Destination    43540 Kleeb Loop
#
#   intersection_directions       city state    zip  plus4
# 0                     NaN     Juneau    AK  99801    NaN  \
# 1                     NaN     Juneau    AK  99801    NaN
# 2                     NaN     Juneau    AK  99801    NaN
# 3                     NaN  Anchorage    AK  99518    NaN
# 4                     NaN   Soldotna    AK  99669    NaN
#
#                 station_phone status_code  ...  cng_fill_type_code cng_psi
# 0                907-780-2222           E  ...                 NaN     NaN  \
# 1                907-586-5226           E  ...                 NaN     NaN
# 2                907-789-2775           E  ...                 NaN     NaN
# 3                888-758-4389           E  ...                 NaN     NaN
# 4  907-398-2931  877-798-3752           E  ...                 NaN     NaN
#
#   cng_vehicle_class lng_vehicle_class  ev_onsite_renewable_source
# 0               NaN               NaN                         NaN  \
# 1               NaN               NaN                         NaN
# 2               NaN               NaN                       HYDRO
# 3               NaN               NaN                         NaN
# 4               NaN               NaN                         NaN
#
#    restricted_access  rd_blends  rd_blends_(french)
# 0                0.0        NaN                 NaN  \
# 1                0.0        NaN                 NaN
# 2                0.0        NaN                 NaN
# 3                NaN        NaN                 NaN
# 4                NaN        NaN                 NaN
#
#    rd_blended_with_biodiesel  rd_maximum_biodiesel_level
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
# [5 rows x 69 columns]

# %%
data.columns
# Out:
# Index(['fuel_type_code', 'station_name', 'street_address',
#        'intersection_directions', 'city', 'state', 'zip', 'plus4',
#        'station_phone', 'status_code', 'expected_date',
#        'groups_with_access_code', 'access_days_time', 'cards_accepted',
#        'bd_blends', 'ng_fill_type_code', 'ng_psi', 'ev_level1_evse_num',
#        'ev_level2_evse_num', 'ev_dc_fast_count', 'ev_other_info', 'ev_network',
#        'ev_network_web', 'geocode_status', 'latitude', 'longitude',
#        'date_last_confirmed', 'id', 'updated_at', 'owner_type_code',
#        'federal_agency_id', 'federal_agency_name', 'open_date',
#        'hydrogen_status_link', 'ng_vehicle_class', 'lpg_primary',
#        'e85_blender_pump', 'ev_connector_types', 'country',
#        'intersection_directions_(french)', 'access_days_time_(french)',
#        'bd_blends_(french)', 'groups_with_access_code_(french)',
#        'hydrogen_is_retail', 'access_code', 'access_detail_code',
#        'federal_agency_code', 'facility_type', 'cng_dispenser_num',
#        'cng_onsite_renewable_source', 'cng_total_compression_capacity',
#        'cng_storage_capacity', 'lng_onsite_renewable_source',
#        'e85_other_ethanol_blends', 'ev_pricing', 'ev_pricing_(french)',
#        'lpg_nozzle_types', 'hydrogen_pressures', 'hydrogen_standards',
#        'cng_fill_type_code', 'cng_psi', 'cng_vehicle_class',
#        'lng_vehicle_class', 'ev_onsite_renewable_source', 'restricted_access',
#        'rd_blends', 'rd_blends_(french)', 'rd_blended_with_biodiesel',
#        'rd_maximum_biodiesel_level'],
#       dtype='object')

# %%
empty = data.loc[:, data.isna().all()]

# %%
data = data.drop(columns=empty.columns)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54238 entries, 0 to 54237
# Data columns (total 38 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   fuel_type_code                    54238 non-null  object
#  1   station_name                      54236 non-null  object
#  2   street_address                    54204 non-null  object
#  3   intersection_directions           2637 non-null   object
#  4   city                              54238 non-null  object
#  5   state                             54236 non-null  object
#  6   zip                               54238 non-null  object
#  7   station_phone                     50826 non-null  object
#  8   status_code                       54238 non-null  object
#  9   groups_with_access_code           54238 non-null  object
#  10  access_days_time                  45802 non-null  object
#  11  cards_accepted                    3978 non-null   object
#  12  ev_level1_evse_num                700 non-null    float64
#  13  ev_level2_evse_num                48014 non-null  float64
#  14  ev_dc_fast_count                  6974 non-null   float64
#  15  ev_other_info                     50 non-null     object
#  16  ev_network                        54236 non-null  object
#  17  ev_network_web                    45117 non-null  object
#  18  geocode_status                    54238 non-null  object
#  19  latitude                          54238 non-null  float64
#  20  longitude                         54238 non-null  float64
#  21  date_last_confirmed               53930 non-null  datetime64[ns]
#  22  id                                54238 non-null  int64
#  23  updated_at                        54238 non-null  object
#  24  owner_type_code                   18066 non-null  object
#  25  federal_agency_id                 1051 non-null   float64
#  26  federal_agency_name               1051 non-null   object
#  27  open_date                         54219 non-null  datetime64[ns]
#  28  ev_connector_types                54190 non-null  object
#  29  country                           54238 non-null  object
#  30  groups_with_access_code_(french)  54238 non-null  object
#  31  access_code                       54238 non-null  object
#  32  access_detail_code                4554 non-null   object
#  33  federal_agency_code               1051 non-null   object
#  34  facility_type                     16733 non-null  object
#  35  ev_pricing                        15314 non-null  object
#  36  ev_onsite_renewable_source        361 non-null    object
#  37  restricted_access                 9105 non-null   float64
# dtypes: datetime64[ns](2), float64(7), int64(1), object(28)
# memory usage: 15.7+ MB

# %%
geo = pd.read_excel(path_geo, engine='openpyxl')

# %%
geo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28338 entries, 0 to 28337
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   city          28338 non-null  object
#  1   city_ascii    28338 non-null  object
#  2   state_id      28338 non-null  object
#  3   state_name    28338 non-null  object
#  4   county_fips   28338 non-null  int64
#  5   county_name   28338 non-null  object
#  6   lat           28338 non-null  float64
#  7   lng           28338 non-null  float64
#  8   population    28338 non-null  int64
#  9   density       28338 non-null  int64
#  10  source        28338 non-null  object
#  11  military      28338 non-null  bool
#  12  incorporated  28338 non-null  bool
#  13  timezone      28338 non-null  object
#  14  ranking       28338 non-null  int64
#  15  zips          28337 non-null  object
#  16  id            28338 non-null  int64
# dtypes: bool(2), float64(2), int64(5), object(8)
# memory usage: 3.3+ MB

# %% [markdown]
# ### Examining sparse columns

# %%
with pd.option_context('display.max_rows', None, 'display.max_colwidth', None):
    display(desc.sort_values('null_values', ascending=False))
# Out:
#                                 name
# 15                     ev_other_info  \
# 36       ev_on-site_renewable_source
# 12                ev_level1_evse_num
# 26               federal_agency_name
# 25                 federal_agency_id
# 33               federal_agency_code
# 3            intersection_directions
# 11                    cards_accepted
# 32                access_detail_code
# 14                  ev_dc_fast_count
# 37                 restricted_access
# 35                        ev_pricing
# 34                     facility_type
# 24                   owner_type_code
# 17                    ev_network_web
# 10                  access_days_time
# 13                ev_level2_evse_num
# 7                      station_phone
# 21               date_last_confirmed
# 28                ev_connector_types
# 2                     street_address
# 27                         open_date
# 5                              state
# 16                        ev_network
# 1                       station_name
# 30  groups_with_access_code_(french)
# 29                           country
# 31                       access_code
# 0                     fuel_type_code
# 23                        updated_at
# 22                                id
# 20                         longitude
# 18                    geocode_status
# 9            groups_with_access_code
# 8                        status_code
# 6                                zip
# 4                               city
# 19                          latitude
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                   desc
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                 NaN  \
# 36                                                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 12                                                                                                                                                                                                                                                                                                                                                                                            For electric stations, the number of Level 1 EVSE ports.
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 33                                                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 3                                                                                                                                                                                                                                                                                                                                                                                        Brief additional information about how to locate the station.
# 11                                                                                                                                                                                                                                                                                                                                    A space-separated list of payment methods accepted. Payment methods are given as code values as described below:
# 32                                                                                                                                                                                                                                                                                                                                                         A description of other station access information, given as code values as described below:
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 37                                                                                                                                                                                                                                                                                                                                                For public stations, an indication of whether the station has restricted access, given as a boolean:
# 35                                                                                                                                                                                                                                                                                                                                                  For electric stations, information about whether and how much users must pay to use the EVSE port.
# 34                                                                                                                                                                                                                                                                                                                                                      The type of facility at which the station is located, given as code values as described below:
# 24                                                                                                                                                                                                                                                                                                                             The type of organization that owns the fueling infrastructure. Owner types are given as code values as described below:
# 17                                                                                                                                                                                                                                                                                                                                                                             For electric stations, the EV charging network Web site, if applicable.
# 10                                                                                                                                                                                                                                                                                                                                                                                                                 Hours of operation for the station.
# 13                                                                                                                                                                                                                                                                                                                                                                                            For electric stations, the number of Level 2 EVSE ports.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                     The phone number of the station.
# 21                                                                                                                                                                                                                                                                                                                                                                                                 The date the station's details were last confirmed.
# 28                                                                                                                                                                                                                                                                                                                    For electric stations, an array of strings identifying the connector types available at this station. Valid connector types are:
# 2                                                                                                                                                                                                                                                                                                                                                                                                        The street address of the station's location.
# 27  The date that the station began offering the fuel. Note that most propane (LPG) stations do not have open dates. Some open dates are approximate. For electric vehicle charging stations added to the Station Locator through automated data feeds from charging networks, this is either the date provided by the charging network or the date it appeared in the Station Locator if the charging network does not provide an open date. See the
# 5                                                                                                                                                                                                                                                                                                                                                  The two character code for the U.S. state or Canadian province/territory of the station's location.
# 16                                                                                                                                                                                                                                                                                                                                                                          For electric stations, the name of the EV charging network, if applicable.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                             The name of the station.
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 29                                                                                                                                                                                                                                                                                                                                                                                           The two character country code of the station's location.
# 31                                                                                                                                                                                                                                                                                                                                                     A description of who is allowed to access the station, given as code values as described below:
# 0                                                                                                                                                                                                                                                                                                                                           The type of alternative fuel the station provides. Fuel types are given as code values as described below:
# 23                                                                                                                                                                                                                                                                                                                                                                                        \n        The time the station's details were last updated (
# 22                                                                                                                                                                                                                                                                                                                                                                                                      A unique identifier for this specific station.
# 20                                                                                                                                                                                                                                                                                                                                    The longitude of the station's address (see the "Geocode Status" field for details on the longitude's accuracy).
# 18                                                                                                                                                                                                                                                                                                      A rating indicating the approximate accuracy of the latitude and longitude for the station's address, given as code values as described below:
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                 Deprecated: See the
# 8                                                                                                                                                                                                                                                                                                                                                                          The current status of the station, given as code values as described below:
# 6                                                                                                                                                                                                                                                                                                                                                                                                The ZIP code (postal code) of the station's location.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                  The city of the station's location.
# 19                                                                                                                                                                                                                                                                                                                                      The latitude of the station's address (see the "Geocode Status" field for details on the latitude's accuracy).
#
#     null_values
# 15        54188
# 36        53877
# 12        53538
# 26        53187
# 25        53187
# 33        53187
# 3         51600
# 11        50260
# 32        49684
# 14        47264
# 37        45133
# 35        38924
# 34        37505
# 24        36172
# 17         9121
# 10         8436
# 13         6224
# 7          3412
# 21          308
# 28           48
# 2            34
# 27           19
# 5             2
# 16            2
# 1             2
# 30            0
# 29            0
# 31            0
# 0             0
# 23            0
# 22            0
# 20            0
# 18            0
# 9             0
# 8             0
# 6             0
# 4             0
# 19            0

# %% [markdown]
# ### NOTE:
#
# Many features still contain null values and other undesirables are still present. Now need to go through each and decide whether the null values can be filled or should be dropped.
#
# Of the **filled/mostly-filled** columns (<10000 null), **keeping**: *latitude, longitude, city, zip, status_code, geocode_status, id, fuel_type_code, access_code, station_name, ev_network, open_date, ev_connector_types, access_days_time, ev_level2_evse_num, date_last_confirmed*
#
# **dropping**:
# <ul>
#     <li><em>groups_with_access_code</em>: deprecated</li>
#     <li><em>groups_with_access_code_(french)</em>: deprecated, french</li>
#     <li><em>city, state, country</em>: geo table will provide all info from <em>zip</em></li>
#     <li><em>updated_at</em>: not necessary</li>
#     <li><em>fuel_type_code</em>: dataset only includes ELEC charging stations</li>
#     <li><em>street_address</em>: geo table will provide info</li>
#     <li><em>station_phone</em>: not necessary</li>
# </ul>
#
# Of the **other columns**, **keeping**: *owner_type_code (useful), facility_type (potentially useful), ev_pricing (useful), restricted_access (useful), ev_dc_fast_count (None => not DC Fast charger?), access_detail_code (access information; useful), ev_level1_evse_num (None => not lvl 1?), ev_on-site_renewable_source(NaN => None; a valid value), federal_agency_code/id/name (None => not federally owned?, interesting data)*
#
# **dropping**:
# <ul>
#     <li><em>cards_accepted</em>: not necessary</li>
#     <li><em>intersection_directions</em>: not necessary</li>
#     <li><em>ev_other_info</em>: only 50 non-null values</li>

# %%
drop = ['groups_with_access_code','groups_with_access_code_(french)','city','state','country','updated_at','fuel_type_code','street_address','station_phone','cards_accepted','intersection_directions', 'ev_other_info']

# %%
data = data.drop(columns=drop)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54238 entries, 0 to 54237
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   station_name                54236 non-null  object
#  1   zip                         54238 non-null  object
#  2   status_code                 54238 non-null  object
#  3   access_days_time            45802 non-null  object
#  4   ev_level1_evse_num          700 non-null    float64
#  5   ev_level2_evse_num          48014 non-null  float64
#  6   ev_dc_fast_count            6974 non-null   float64
#  7   ev_network                  54236 non-null  object
#  8   ev_network_web              45117 non-null  object
#  9   geocode_status              54238 non-null  object
#  10  latitude                    54238 non-null  float64
#  11  longitude                   54238 non-null  float64
#  12  date_last_confirmed         53930 non-null  datetime64[ns]
#  13  id                          54238 non-null  int64
#  14  owner_type_code             18066 non-null  object
#  15  federal_agency_id           1051 non-null   float64
#  16  federal_agency_name         1051 non-null   object
#  17  open_date                   54219 non-null  datetime64[ns]
#  18  ev_connector_types          54190 non-null  object
#  19  access_code                 54238 non-null  object
#  20  access_detail_code          4554 non-null   object
#  21  federal_agency_code         1051 non-null   object
#  22  facility_type               16733 non-null  object
#  23  ev_pricing                  15314 non-null  object
#  24  ev_onsite_renewable_source  361 non-null    object
#  25  restricted_access           9105 non-null   float64
# dtypes: datetime64[ns](2), float64(7), int64(1), object(16)
# memory usage: 10.8+ MB

# %%
print(list(data.columns))
# Out:
# ['station_name', 'zip', 'status_code', 'access_days_time', 'ev_level1_evse_num', 'ev_level2_evse_num', 'ev_dc_fast_count', 'ev_network', 'ev_network_web', 'geocode_status', 'latitude', 'longitude', 'date_last_confirmed', 'id', 'owner_type_code', 'federal_agency_id', 'federal_agency_name', 'open_date', 'ev_connector_types', 'access_code', 'access_detail_code', 'federal_agency_code', 'facility_type', 'ev_pricing', 'ev_onsite_renewable_source', 'restricted_access']

# %%
lvl1 = data.loc[~data['ev_level1_evse_num'].isna(), ['id']]
lvl2 = data.loc[~data['ev_level2_evse_num'].isna(), ['id']]
lvl3 = data.loc[~data['ev_dc_fast_count'].isna(), ['id']]

# %%
l12 = lvl1.isin(lvl2).sum()
l13 = lvl1.isin(lvl3).sum()
l23 = lvl2.isin(lvl3).sum()
print(f'1 and 2: {l12}, \n1 and 3: {l13}, \n2 and 3: {l23}')
# Out:
# 1 and 2: id    219
# dtype: int64,
# 1 and 3: id    7
# dtype: int64,
# 2 and 3: id    1234
# dtype: int64

# %%
total_w_ports = (lvl1.shape[0] + lvl2.shape[0] + lvl3.shape[0] - (l12+l13+l23))[0]
print(f'{total_w_ports} out of {data.shape[0]} stations have charger levels associated with them')
# Out:
# 54228 out of 54238 stations have charger levels associated with them

# %%
unknown_chargers = data.loc[data['ev_level1_evse_num'].isna() & data['ev_level2_evse_num'].isna() & data['ev_dc_fast_count'].isna(), :]

# %%
charge_cols = ['ev_level1_evse_num', 'ev_level2_evse_num', 'ev_dc_fast_count']

# %%
# Charger level count: changing nan to 0
data[charge_cols] = data[charge_cols].fillna(0)
# No info available on chargers here
data.loc[unknown_chargers.index, charge_cols] = np.nan

# %%
data.loc[unknown_chargers.index, :]
# Out:
#                                        station_name    zip status_code  \
# 1636                                  Bristol Farms  91030           E
# 1653                            Japan Center Garage  94115           E
# 1708                         Vallejo Ferry Terminal  94590           E
# 2388   City of Sacramento - Department of Utilities  95822           E
# 18030                           CDPS CBI Arvada Lab  80002           E
# 31510            DTE Energy - Macomb Service Center  48038           E
# 42919       Forest Service - Umpqua National Forest  97443           E
#
#               access_days_time  ev_level1_evse_num  ev_level2_evse_num  \
# 1636            24 hours daily                 NaN                 NaN
# 1653   24 hours daily; pay lot                 NaN                 NaN
# 1708            24 hours daily                 NaN                 NaN
# 2388                       NaN                 NaN                 NaN
# 18030                      NaN                 NaN                 NaN
# 31510           24 hours daily                 NaN                 NaN
# 42919      USDA fleet use only                 NaN                 NaN
#
#        ev_dc_fast_count     ev_network ev_network_web geocode_status  ...  \
# 1636                NaN  Non-Networked            NaN          200-9  ...
# 1653                NaN  Non-Networked            NaN            GPS  ...
# 1708                NaN  Non-Networked            NaN          200-8  ...
# 2388                NaN  Non-Networked            NaN          200-9  ...
# 18030               NaN            NaN            NaN          200-8  ...
# 31510               NaN  Non-Networked            NaN            GPS  ...
# 42919               NaN            NaN            NaN          200-9  ...
#
#                   federal_agency_name  open_date ev_connector_types  \
# 1636                              NaN 1997-08-31                NaN
# 1653                              NaN 2002-01-31                NaN
# 1708                              NaN 2005-07-15                NaN
# 2388                              NaN 2017-04-01                NaN
# 18030                             NaN 2020-07-06                NaN
# 31510                             NaN 2010-01-01                NaN
# 42919  U.S. Department of Agriculture 2013-06-30                NaN
#
#        access_code  access_detail_code  federal_agency_code   facility_type  \
# 1636        public                 NaN                  NaN         GROCERY
# 1653        public  CREDIT_CARD_ALWAYS                  NaN  PARKING_GARAGE
# 1708        public                 NaN                  NaN   TRAVEL_CENTER
# 2388       private                 NaN                  NaN        MUNI_GOV
# 18030      private                 NaN                  NaN             NaN
# 31510       public                 NaN                  NaN         UTILITY
# 42919      private                 NaN                 USDA       NATL_PARK
#
#       ev_pricing ev_on-site_renewable_source restricted_access
# 1636         NaN                         NaN               0.0
# 1653         NaN                         NaN               0.0
# 1708        Free                         NaN               0.0
# 2388         NaN                         NaN               NaN
# 18030        NaN                         NaN               NaN
# 31510       Free                         NaN               0.0
# 42919        NaN                         NaN               NaN
#
# [7 rows x 26 columns]
